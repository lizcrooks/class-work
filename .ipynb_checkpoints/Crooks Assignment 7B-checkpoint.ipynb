# %%
import pandas as pd
df = pd.read_csv("NOAH Weather Seattle Area 1-1 to 5-13-2018 (Subset).csv")
df.head()
# Out:
#        STATION                  NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0  US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 1  US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 2  US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 3  US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 4  US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
#
#        DATE  PRCP  SNOW  SNWD  TempAvg  TempMax  TempMin  Fog  Thunder  \
# 0  1/1/2018  0.00   0.0   NaN      NaN      NaN      NaN  NaN      NaN
# 1  1/2/2018  0.00   NaN   NaN      NaN      NaN      NaN  NaN      NaN
# 2  1/3/2018  0.00   0.0   NaN      NaN      NaN      NaN  NaN      NaN
# 3  1/4/2018  0.01   NaN   NaN      NaN      NaN      NaN  NaN      NaN
# 4  1/5/2018  0.26   NaN   NaN      NaN      NaN      NaN  NaN      NaN
#
#    Ice Pellets  Hail  Smoke
# 0          NaN   NaN    NaN
# 1          NaN   NaN    NaN
# 2          NaN   NaN    NaN
# ...

# %%
g = df.groupby('NAME')
g

# %%
for NAME, NAME_df in g:
    print(NAME)
    print(NAME_df)
# Out:
# AUBURN 8.2 SE, WA US
#          STATION                  NAME  LATITUDE  LONGITUDE  ELEVATION  \
# 0    US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 1    US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 2    US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 3    US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 4    US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 5    US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 6    US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 7    US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 8    US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 9    US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 10   US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 11   US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# ...

# %%
g.get_group('KENT, WA US')
# Out:
#           STATION         NAME  LATITUDE  LONGITUDE  ELEVATION       DATE  \
# 4858  USC00454169  KENT, WA US   47.4172  -122.2433        9.1   1/1/2018
# 4859  USC00454169  KENT, WA US   47.4172  -122.2433        9.1   1/3/2018
# 4860  USC00454169  KENT, WA US   47.4172  -122.2433        9.1   1/4/2018
# 4861  USC00454169  KENT, WA US   47.4172  -122.2433        9.1   1/5/2018
# 4862  USC00454169  KENT, WA US   47.4172  -122.2433        9.1   1/6/2018
# 4863  USC00454169  KENT, WA US   47.4172  -122.2433        9.1   1/7/2018
# 4864  USC00454169  KENT, WA US   47.4172  -122.2433        9.1   1/8/2018
# 4865  USC00454169  KENT, WA US   47.4172  -122.2433        9.1   1/9/2018
# 4866  USC00454169  KENT, WA US   47.4172  -122.2433        9.1  1/10/2018
# 4867  USC00454169  KENT, WA US   47.4172  -122.2433        9.1  1/11/2018
# 4868  USC00454169  KENT, WA US   47.4172  -122.2433        9.1  1/12/2018
# 4869  USC00454169  KENT, WA US   47.4172  -122.2433        9.1  1/13/2018
# ...

# %%
df.pivot(index="DATE",columns="NAME",values="PRCP").max()
#How much precipitation did each weather station get from January to May?
# Out:
# NAME
# AUBURN 8.2 SE, WA US                                 1.05
# BAINBRIDGE ISLAND 2.4 SW, WA US                      1.10
# BAINBRIDGE ISLAND 2.6 NNW, WA US                     1.01
# BAINBRIDGE ISLAND 2.6 NW, WA US                      1.69
# BELFAIR 3.2 WSW, WA US                               2.33
# BELLEVUE 1.1 SE, WA US                               1.40
# BELLEVUE 1.8 W, WA US                                1.92
# BELLEVUE 2.3 SSE, WA US                              1.41
# BOTHELL 4.9 NNW, WA US                               1.28
# BOTHELL 5.4 N, WA US                                 1.38
# BREMERTON 1.8 NE, WA US                              1.74
# BREMERTON 2.8 NE, WA US                              1.70
# BREMERTON 2.9 NNE, WA US                             1.17
# BREMERTON, WA US                                     1.90
# BRIER 0.7 WSW, WA US                                 1.26
# BRINNON 1.7 WSW, WA US                               2.03
# ...

# %%
new_df.pivot(index="DATE",columns="NAME",values="SNOW").max()
#What weather station got the most snow over the period from January to May?
# Out:
# NAME
# AUBURN 8.2 SE, WA US                                 4.5
# BAINBRIDGE ISLAND 2.4 SW, WA US                      2.0
# BAINBRIDGE ISLAND 2.6 NNW, WA US                     1.9
# BAINBRIDGE ISLAND 2.6 NW, WA US                      1.8
# BELFAIR 3.2 WSW, WA US                               0.0
# BELLEVUE 1.1 SE, WA US                               0.0
# BELLEVUE 1.8 W, WA US                                0.6
# BELLEVUE 2.3 SSE, WA US                              0.7
# BOTHELL 4.9 NNW, WA US                               1.2
# BOTHELL 5.4 N, WA US                                 0.7
# BREMERTON 1.8 NE, WA US                              2.1
# BREMERTON 2.8 NE, WA US                              0.0
# BREMERTON 2.9 NNE, WA US                             NaN
# BREMERTON, WA US                                     1.7
# BRIER 0.7 WSW, WA US                                 0.5
# BRINNON 1.7 WSW, WA US                               0.0
# ...

# %%
df.set_index('DATE', inplace=True)
df.head()
# Out:
#               STATION                  NAME  LATITUDE  LONGITUDE  ELEVATION  \
# DATE
# 1/1/2018  US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 1/2/2018  US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 1/3/2018  US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 1/4/2018  US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
# 1/5/2018  US1WAKG0070  AUBURN 8.2 SE, WA US   47.2643  -122.0666      170.1
#
#           PRCP  SNOW  SNWD  TempAvg  TempMax  TempMin  Fog  Thunder  \
# DATE
# 1/1/2018  0.00   0.0   NaN      NaN      NaN      NaN  NaN      NaN
# 1/2/2018  0.00   NaN   NaN      NaN      NaN      NaN  NaN      NaN
# 1/3/2018  0.00   0.0   NaN      NaN      NaN      NaN  NaN      NaN
# 1/4/2018  0.01   NaN   NaN      NaN      NaN      NaN  NaN      NaN
# 1/5/2018  0.26   NaN   NaN      NaN      NaN      NaN  NaN      NaN
#
#           Ice Pellets  Hail  Smoke
# DATE
# 1/1/2018          NaN   NaN    NaN
# ...

# %%
df.loc['4/24/2018'].head()
#What was the weather like on my birthday in the Seattle area last year?
# Out:
#                STATION                              NAME  LATITUDE  LONGITUDE  \
# DATE
# 4/24/2018  US1WAKG0070              AUBURN 8.2 SE, WA US   47.2643  -122.0666
# 4/24/2018  US1WAKP0020   BAINBRIDGE ISLAND 2.4 SW, WA US   47.6297  -122.5686
# 4/24/2018  US1WAKP0006  BAINBRIDGE ISLAND 2.6 NNW, WA US   47.6919  -122.5498
# 4/24/2018  US1WAKG0231            BELLEVUE 1.1 SE, WA US   47.5940  -122.1363
# 4/24/2018  US1WAKG0065             BELLEVUE 1.8 W, WA US   47.6046  -122.1931
#
#            ELEVATION  PRCP  SNOW  SNWD  TempAvg  TempMax  TempMin  Fog  \
# DATE
# 4/24/2018      170.1   0.0   0.0   NaN      NaN      NaN      NaN  NaN
# 4/24/2018      109.4   0.0   0.0   NaN      NaN      NaN      NaN  NaN
# 4/24/2018        7.0   0.0   0.0   NaN      NaN      NaN      NaN  NaN
# 4/24/2018      109.4   0.0   0.0   NaN      NaN      NaN      NaN  NaN
# 4/24/2018       27.1   0.0   0.0   NaN      NaN      NaN      NaN  NaN
#
#            Thunder  Ice Pellets  Hail  Smoke
# DATE
# ...
